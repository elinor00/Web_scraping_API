# %%
#!pip install openpyxl
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 5.0 MB/s eta 0:00:0000:01
# ...

# %%
import pandas as pd

# %%
import requests
import json

MY_API_KEY = 'tYMb-JGIK38qCtpE69UrF6sAE6kCOwstiESR5Xja1EVcv_zhT0IJxse6CwFitY7YpvqWpjXE6qhivRCdPml8EOixjd8qf1q-4iTwelHFR0mCL28PRu6bRc7vW5o0ZHYx'
latitude = 40.810299
longitude = -73.628403

# Set up the endpoint URL and parameters
url = 'https://api.yelp.com/v3/businesses/search'
headers = {'Authorization': 'Bearer ' + MY_API_KEY}
params = {"latitude": latitude, "longitude": longitude, "categories": "restaurants", "limit": 10}

response = requests.get(url, headers=headers, params=params)

# %%
df = pd.DataFrame(data['businesses'])
df
# Out:
#                        id                                      alias  \
# 0  efnvaYbV4hWCa_XWjeaTVw                       bar-frites-greenvale
# 1  M1cXcwpN_QZZT27rqA2MWw                       sarin-thai-greenvale
# 2  2NTiQhxKk44mfH-BePunfQ  besito-mexican-restaurant-roslyn-roslyn-3
# 3  55o1f2dpKCdFVgJeIOk5XA             mims-restaurant-roslyn-heights
# 4  s2kDC_kY7uqsWJ7jkJ_EMA                     gatsbys-landing-roslyn
# 5  y_pEXfWX9l3ZcjsE4pHpGQ                  copperhill-williston-park
# 6  U2ybcU2xDuk1o91VNWEBlA                    centro-cucina-greenvale
# 7  tTQ7u5HOEaOeiTs4fH1RUA                meritage-wine-bar-glen-cove
# 8  32CvgNcoc5A1lj7ioLzUQQ                              kyma-roslyn-2
# 9  vfnS8azG-POk-txJB05XEA              biscuits-and-barbeque-mineola
#
#                                  name  \
# 0                          Bar Frites
# 1                          Sarin Thai
# 2  Besito Mexican Restaurant - Roslyn
# 3                    Mim's Restaurant
# ...

# %%
df.to_excel('restaurants.xlsx', index = False)

# %%
df = pd.read_excel('restaurants.xlsx')
print(df.head(10))
# Out:
#                        id                                      alias  \
# 0  efnvaYbV4hWCa_XWjeaTVw                       bar-frites-greenvale
# 1  M1cXcwpN_QZZT27rqA2MWw                       sarin-thai-greenvale
# 2  2NTiQhxKk44mfH-BePunfQ  besito-mexican-restaurant-roslyn-roslyn-3
# 3  55o1f2dpKCdFVgJeIOk5XA             mims-restaurant-roslyn-heights
# 4  s2kDC_kY7uqsWJ7jkJ_EMA                     gatsbys-landing-roslyn
# 5  y_pEXfWX9l3ZcjsE4pHpGQ                  copperhill-williston-park
# 6  U2ybcU2xDuk1o91VNWEBlA                    centro-cucina-greenvale
# 7  tTQ7u5HOEaOeiTs4fH1RUA                meritage-wine-bar-glen-cove
# 8  32CvgNcoc5A1lj7ioLzUQQ                              kyma-roslyn-2
# 9  vfnS8azG-POk-txJB05XEA              biscuits-and-barbeque-mineola
#
#                                  name  \
# 0                          Bar Frites
# 1                          Sarin Thai
# 2  Besito Mexican Restaurant - Roslyn
# 3                    Mim's Restaurant
# ...

# %%
# Make the API request
response = requests.get(url, headers=headers, params=params)

# Parse the response
data = json.loads(response.text)




# Extract the data
restaurants = []
for business in data['businesses']:
    name = business['name']
    address = ', '.join(business['location']['display_address'])
    restaurants.append({'Name': name, 'Address': address})

# Print the data
for restaurant in restaurants:
    print(restaurant['Name'], restaurant['Address'])
# Out:
# Bar Frites 400 Wheatley Plz, Greenvale, NY 11548
# Sarin Thai 43 Glen Cove Rd, Greenvale, NY 11548
# Besito Mexican Restaurant - Roslyn 1516 Old Northern Blvd, Roslyn, NY 11576
# Mim's Restaurant 235 Roslyn Rd, Roslyn Heights, NY 11577
# Gatsby's Landing 1362 Old Northern Blvd, Roslyn, NY 11576
# Copperhill 234 Hillside Ave, Williston Park, NY 11596
# Centro Cucina 43C Glen Cove Rd, Greenvale, NY 11548
# Meritage Wine Bar 90 School St, Glen Cove, NY 11542
# Kyma 1446 Old Northern Blvd, Roslyn, NY 11576
# Biscuits & Barbeque 106 E 2nd St, Mineola, NY 11501
